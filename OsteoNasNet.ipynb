# %% [markdown]
# <a href="https://colab.research.google.com/github/RXX17/CoIuKTLM/blob/main/OsteoNasNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from keras.applications.nasnet import NASNetLarge
#from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.nasnet import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
# Image size and loading datasets
IMAGE_SIZE = (331, 331, 3)

train_path = '/content/drive/MyDrive/Split/train'
valid_path = '/content/drive/MyDrive/Split/val'

# %%
# Import the Vgg 16 library as shown below and add preprocessing layer to the front of VGG
# Here we will be using imagenet weights

nasnet = NASNetLarge(input_shape=IMAGE_SIZE, weights='imagenet', include_top=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large-no-top.h5
# 343610240/343610240 [==============================] - 2s 0us/step

# %%
# don't train existing weights
for layer in nasnet.layers:
    layer.trainable = False

# %%
  # useful for getting number of output classes
folders = glob('/content/drive/MyDrive/Split/train/*')

# %%
# our layers - you can add more if you want
x = Flatten()(nasnet.output)

# %%
prediction = Dense(len(folders), activation='softmax')(x)

# create a model object
model = Model(inputs=nasnet.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 331, 331, 3  0           []
#                                 )]
#
#  stem_conv1 (Conv2D)            (None, 165, 165, 96  2592        ['input_1[0][0]']
#                                 )
#
#  stem_bn1 (BatchNormalization)  (None, 165, 165, 96  384         ['stem_conv1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_conv_1_stem_1 (Conv2  (None, 165, 165, 42  4032       ['activation[0][0]']
#  D)                             )
#
#  reduction_bn_1_stem_1 (BatchNo  (None, 165, 165, 42  168        ['reduction_conv_1_stem_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 165, 165, 42  0           ['reduction_bn_1_stem_1[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_1_pad_reduction  (None, 169, 169, 42  0          ['activation_1[0][0]']
#  _left1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_pad_reduction  (None, 171, 171, 96  0          ['activation_3[0][0]']
#  _right1_stem_1 (ZeroPadding2D)  )
#
#  separable_conv_1_reduction_lef  (None, 83, 83, 42)  2814        ['separable_conv_1_pad_reduction_
#  t1_stem_1 (SeparableConv2D)                                     left1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 83, 83, 42)  8736        ['separable_conv_1_pad_reduction_
#  ht1_stem_1 (SeparableConv2D)                                    right1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  activation_2 (Activation)      (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_1[0][0]']
#
#  activation_4 (Activation)      (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 83, 83, 42)  2814        ['activation_2[0][0]']
#  t1_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 83, 83, 42)  3822        ['activation_4[0][0]']
#  ht1_stem_1 (SeparableConv2D)
#
#  activation_5 (Activation)      (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_left
#  left1_stem_1 (BatchNormalizati                                  1_stem_1[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_righ
#  right1_stem_1 (BatchNormalizat                                  t1_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 171, 171, 96  0          ['activation_5[0][0]']
#  _right2_stem_1 (ZeroPadding2D)  )
#
#  activation_7 (Activation)      (None, 165, 165, 96  0           ['stem_bn1[0][0]']
#                                 )
#
#  reduction_add_1_stem_1 (Add)   (None, 83, 83, 42)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_1[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 83, 83, 42)  8736        ['separable_conv_1_pad_reduction_
#  ht2_stem_1 (SeparableConv2D)                                    right2_stem_1[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 169, 169, 96  0          ['activation_7[0][0]']
#  _right3_stem_1 (ZeroPadding2D)  )
#
#  activation_9 (Activation)      (None, 83, 83, 42)   0           ['reduction_add_1_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 83, 83, 42)  6432        ['separable_conv_1_pad_reduction_
#  ht3_stem_1 (SeparableConv2D)                                    right3_stem_1[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 83, 83, 42)  2142        ['activation_9[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  activation_6 (Activation)      (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_1_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_pad_1_stem_1 (ZeroPa  (None, 167, 167, 42  0          ['reduction_bn_1_stem_1[0][0]']
#  dding2D)                       )
#
#  separable_conv_2_reduction_rig  (None, 83, 83, 42)  3822        ['activation_6[0][0]']
#  ht2_stem_1 (SeparableConv2D)
#
#  activation_8 (Activation)      (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  activation_10 (Activation)     (None, 83, 83, 42)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (MaxPoo  (None, 83, 83, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_righ
#  right2_stem_1 (BatchNormalizat                                  t2_stem_1[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 83, 83, 42)  2814        ['activation_8[0][0]']
#  ht3_stem_1 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 83, 83, 42)  2142        ['activation_10[0][0]']
#  t4_stem_1 (SeparableConv2D)
#
#  adjust_relu_1_stem_2 (Activati  (None, 165, 165, 96  0          ['stem_bn1[0][0]']
#  on)                            )
#
#  reduction_add_2_stem_1 (Add)   (None, 83, 83, 42)   0           ['reduction_left2_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Averag  (None, 83, 83, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_righ
#  right3_stem_1 (BatchNormalizat                                  t3_stem_1[0][0]']
#  ion)
#
#  reduction_left4_stem_1 (Averag  (None, 83, 83, 42)  0           ['reduction_add_1_stem_1[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 83, 83, 42)  168         ['separable_conv_2_reduction_left
#  left4_stem_1 (BatchNormalizati                                  4_stem_1[0][0]']
#  on)
#
#  reduction_right5_stem_1 (MaxPo  (None, 83, 83, 42)  0           ['reduction_pad_1_stem_1[0][0]']
#  oling2D)
#
#  zero_padding2d (ZeroPadding2D)  (None, 166, 166, 96  0          ['adjust_relu_1_stem_2[0][0]']
#                                 )
#
#  reduction_add3_stem_1 (Add)    (None, 83, 83, 42)   0           ['reduction_left3_stem_1[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_1[0][0]']
#
#  add (Add)                      (None, 83, 83, 42)   0           ['reduction_add_2_stem_1[0][0]',
#                                                                   'reduction_left4_stem_1[0][0]']
#
#  reduction_add4_stem_1 (Add)    (None, 83, 83, 42)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_1[0][0]',
#                                                                   'reduction_right5_stem_1[0][0]']
#
#  cropping2d (Cropping2D)        (None, 165, 165, 96  0           ['zero_padding2d[0][0]']
#                                 )
#
#  reduction_concat_stem_1 (Conca  (None, 83, 83, 168)  0          ['reduction_add_2_stem_1[0][0]',
#  tenate)                                                          'reduction_add3_stem_1[0][0]',
#                                                                   'add[0][0]',
#                                                                   'reduction_add4_stem_1[0][0]']
#
#  adjust_avg_pool_1_stem_2 (Aver  (None, 83, 83, 96)  0           ['adjust_relu_1_stem_2[0][0]']
#  agePooling2D)
#
#  adjust_avg_pool_2_stem_2 (Aver  (None, 83, 83, 96)  0           ['cropping2d[0][0]']
#  agePooling2D)
#
#  activation_11 (Activation)     (None, 83, 83, 168)  0           ['reduction_concat_stem_1[0][0]']
#
#  adjust_conv_1_stem_2 (Conv2D)  (None, 83, 83, 42)   4032        ['adjust_avg_pool_1_stem_2[0][0]'
#                                                                  ]
#
#  adjust_conv_2_stem_2 (Conv2D)  (None, 83, 83, 42)   4032        ['adjust_avg_pool_2_stem_2[0][0]'
#                                                                  ]
#
#  reduction_conv_1_stem_2 (Conv2  (None, 83, 83, 84)  14112       ['activation_11[0][0]']
#  D)
#
#  concatenate (Concatenate)      (None, 83, 83, 84)   0           ['adjust_conv_1_stem_2[0][0]',
#                                                                   'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (BatchNo  (None, 83, 83, 84)  336         ['reduction_conv_1_stem_2[0][0]']
#  rmalization)
#
#  adjust_bn_stem_2 (BatchNormali  (None, 83, 83, 84)  336         ['concatenate[0][0]']
#  zation)
#
#  activation_12 (Activation)     (None, 83, 83, 84)   0           ['reduction_bn_1_stem_2[0][0]']
#
#  activation_14 (Activation)     (None, 83, 83, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 87, 87, 84)  0           ['activation_12[0][0]']
#  _left1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_pad_reduction  (None, 89, 89, 84)  0           ['activation_14[0][0]']
#  _right1_stem_2 (ZeroPadding2D)
#
#  separable_conv_1_reduction_lef  (None, 42, 42, 84)  9156        ['separable_conv_1_pad_reduction_
#  t1_stem_2 (SeparableConv2D)                                     left1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 42, 42, 84)  11172       ['separable_conv_1_pad_reduction_
#  ht1_stem_2 (SeparableConv2D)                                    right1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  activation_13 (Activation)     (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft1_stem_2[0][0]']
#
#  activation_15 (Activation)     (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_2_reduction_lef  (None, 42, 42, 84)  9156        ['activation_13[0][0]']
#  t1_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_rig  (None, 42, 42, 84)  11172       ['activation_15[0][0]']
#  ht1_stem_2 (SeparableConv2D)
#
#  activation_16 (Activation)     (None, 83, 83, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_left
#  left1_stem_2 (BatchNormalizati                                  1_stem_2[0][0]']
#  on)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_righ
#  right1_stem_2 (BatchNormalizat                                  t1_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_pad_reduction  (None, 89, 89, 84)  0           ['activation_16[0][0]']
#  _right2_stem_2 (ZeroPadding2D)
#
#  activation_18 (Activation)     (None, 83, 83, 84)   0           ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Add)   (None, 42, 42, 84)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft1_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight1_stem_2[0][0]']
#
#  separable_conv_1_reduction_rig  (None, 42, 42, 84)  11172       ['separable_conv_1_pad_reduction_
#  ht2_stem_2 (SeparableConv2D)                                    right2_stem_2[0][0]']
#
#  separable_conv_1_pad_reduction  (None, 87, 87, 84)  0           ['activation_18[0][0]']
#  _right3_stem_2 (ZeroPadding2D)
#
#  activation_20 (Activation)     (None, 42, 42, 84)   0           ['reduction_add_1_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_reduction_rig  (None, 42, 42, 84)  9156        ['separable_conv_1_pad_reduction_
#  ht3_stem_2 (SeparableConv2D)                                    right3_stem_2[0][0]']
#
#  separable_conv_1_reduction_lef  (None, 42, 42, 84)  7812        ['activation_20[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  activation_17 (Activation)     (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  separable_conv_1_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_1_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_pad_1_stem_2 (ZeroPa  (None, 85, 85, 84)  0           ['reduction_bn_1_stem_2[0][0]']
#  dding2D)
#
#  separable_conv_2_reduction_rig  (None, 42, 42, 84)  11172       ['activation_17[0][0]']
#  ht2_stem_2 (SeparableConv2D)
#
#  activation_19 (Activation)     (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  activation_21 (Activation)     (None, 42, 42, 84)   0           ['separable_conv_1_bn_reduction_l
#                                                                  eft4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (MaxPoo  (None, 42, 42, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  ling2D)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_righ
#  right2_stem_2 (BatchNormalizat                                  t2_stem_2[0][0]']
#  ion)
#
#  separable_conv_2_reduction_rig  (None, 42, 42, 84)  9156        ['activation_19[0][0]']
#  ht3_stem_2 (SeparableConv2D)
#
#  separable_conv_2_reduction_lef  (None, 42, 42, 84)  7812        ['activation_21[0][0]']
#  t4_stem_2 (SeparableConv2D)
#
#  adjust_relu_1_0 (Activation)   (None, 83, 83, 168)  0           ['reduction_concat_stem_1[0][0]']
#
#  reduction_add_2_stem_2 (Add)   (None, 42, 42, 84)   0           ['reduction_left2_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Averag  (None, 42, 42, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_righ
#  right3_stem_2 (BatchNormalizat                                  t3_stem_2[0][0]']
#  ion)
#
#  reduction_left4_stem_2 (Averag  (None, 42, 42, 84)  0           ['reduction_add_1_stem_2[0][0]']
#  ePooling2D)
#
#  separable_conv_2_bn_reduction_  (None, 42, 42, 84)  336         ['separable_conv_2_reduction_left
#  left4_stem_2 (BatchNormalizati                                  4_stem_2[0][0]']
#  on)
#
#  reduction_right5_stem_2 (MaxPo  (None, 42, 42, 84)  0           ['reduction_pad_1_stem_2[0][0]']
#  oling2D)
#
#  zero_padding2d_1 (ZeroPadding2  (None, 84, 84, 168)  0          ['adjust_relu_1_0[0][0]']
#  D)
#
#  reduction_add3_stem_2 (Add)    (None, 42, 42, 84)   0           ['reduction_left3_stem_2[0][0]',
#                                                                   'separable_conv_2_bn_reduction_r
#                                                                  ight3_stem_2[0][0]']
#
#  add_1 (Add)                    (None, 42, 42, 84)   0           ['reduction_add_2_stem_2[0][0]',
#                                                                   'reduction_left4_stem_2[0][0]']
#
#  reduction_add4_stem_2 (Add)    (None, 42, 42, 84)   0           ['separable_conv_2_bn_reduction_l
#                                                                  eft4_stem_2[0][0]',
#                                                                   'reduction_right5_stem_2[0][0]']
#
#  cropping2d_1 (Cropping2D)      (None, 83, 83, 168)  0           ['zero_padding2d_1[0][0]']
#
#  reduction_concat_stem_2 (Conca  (None, 42, 42, 336)  0          ['reduction_add_2_stem_2[0][0]',
#  tenate)                                                          'reduction_add3_stem_2[0][0]',
#                                                                   'add_1[0][0]',
#                                                                   'reduction_add4_stem_2[0][0]']
#
#  adjust_avg_pool_1_0 (AveragePo  (None, 42, 42, 168)  0          ['adjust_relu_1_0[0][0]']
#  oling2D)
#
#  adjust_avg_pool_2_0 (AveragePo  (None, 42, 42, 168)  0          ['cropping2d_1[0][0]']
#  oling2D)
#
#  adjust_conv_1_0 (Conv2D)       (None, 42, 42, 84)   14112       ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)       (None, 42, 42, 84)   14112       ['adjust_avg_pool_2_0[0][0]']
#
#  activation_22 (Activation)     (None, 42, 42, 336)  0           ['reduction_concat_stem_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 42, 42, 168)  0           ['adjust_conv_1_0[0][0]',
#                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)       (None, 42, 42, 168)  56448       ['activation_22[0][0]']
#
#  adjust_bn_0 (BatchNormalizatio  (None, 42, 42, 168)  672        ['concatenate_1[0][0]']
#  n)
#
#  normal_bn_1_0 (BatchNormalizat  (None, 42, 42, 168)  672        ['normal_conv_1_0[0][0]']
#  ion)
#
#  activation_23 (Activation)     (None, 42, 42, 168)  0           ['normal_bn_1_0[0][0]']
#
#  activation_25 (Activation)     (None, 42, 42, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_27 (Activation)     (None, 42, 42, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_29 (Activation)     (None, 42, 42, 168)  0           ['adjust_bn_0[0][0]']
#
#  activation_31 (Activation)     (None, 42, 42, 168)  0           ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 42, 42, 168)  32424      ['activation_23[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 42, 42, 168)  29736      ['activation_25[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 42, 42, 168)  32424      ['activation_27[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 42, 42, 168)  29736      ['activation_29[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 42, 42, 168)  29736      ['activation_31[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_1_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_1_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_1_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_1_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_1_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  activation_24 (Activation)     (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  1_0[0][0]']
#
#  activation_26 (Activation)     (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  activation_28 (Activation)     (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  2_0[0][0]']
#
#  activation_30 (Activation)     (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_0[0][0]']
#
#  activation_32 (Activation)     (None, 42, 42, 168)  0           ['separable_conv_1_bn_normal_left
#                                                                  5_0[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 42, 42, 168)  32424      ['activation_24[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 42, 42, 168)  29736      ['activation_26[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 42, 42, 168)  32424      ['activation_28[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 42, 42, 168)  29736      ['activation_30[0][0]']
#  _0 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 42, 42, 168)  29736      ['activation_32[0][0]']
#  0 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_2_normal_left1_0
#  t1_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_2_normal_right1_
#  ht1_0 (BatchNormalization)                                      0[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_2_normal_left2_0
#  t2_0 (BatchNormalization)                                       [0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 42, 42, 168)  672        ['separable_conv_2_normal_right2_
#  ht2_0 (BatchNormalization)                                      0[0][0]']
#
#  normal_left3_0 (AveragePooling  (None, 42, 42, 168)  0          ['normal_bn_1_0[0][0]']
#  2D)
#
#  normal_left4_0 (AveragePooling  (None, 42, 42, 168)  0          ['adjust_bn_0[0][0]']
#  2D)
#
#  normal_right4_0 (AveragePoolin  (None, 42, 42, 168)  0          ['adjust_bn_0[0][0]']
#  g2D)
#
#  separable_conv_2_bn_normal_lef  (None, 42, 42, 168)  672        ['separable_conv_2_normal_left5_0
#  t5_0 (BatchNormalization)                                       [0][0]']
#
#  normal_add_1_0 (Add)           (None, 42, 42, 168)  0           ['separable_conv_2_bn_normal_left
#                                                                  1_0[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_0[0][0]']
#
#  normal_add_2_0 (Add)           (None, 42, 42, 168)  0           ['separable_conv_2_bn_normal_left
# ...
#                                                                   'normal_right4_17[0][0]']
#
#  normal_add_5_17 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  5_17[0][0]',
#                                                                   'normal_bn_1_17[0][0]']
#
#  normal_concat_17 (Concatenate)  (None, 11, 11, 4032  0          ['adjust_bn_17[0][0]',
#                                 )                                 'normal_add_1_17[0][0]',
#                                                                   'normal_add_2_17[0][0]',
#                                                                   'normal_add_3_17[0][0]',
#                                                                   'normal_add_4_17[0][0]',
#                                                                   'normal_add_5_17[0][0]']
#
#  activation_247 (Activation)    (None, 11, 11, 4032  0           ['normal_concat_16[0][0]']
#                                 )
#
#  activation_248 (Activation)    (None, 11, 11, 4032  0           ['normal_concat_17[0][0]']
#                                 )
#
#  adjust_conv_projection_18 (Con  (None, 11, 11, 672)  2709504    ['activation_247[0][0]']
#  v2D)
#
#  normal_conv_1_18 (Conv2D)      (None, 11, 11, 672)  2709504     ['activation_248[0][0]']
#
#  adjust_bn_18 (BatchNormalizati  (None, 11, 11, 672)  2688       ['adjust_conv_projection_18[0][0]
#  on)                                                             ']
#
#  normal_bn_1_18 (BatchNormaliza  (None, 11, 11, 672)  2688       ['normal_conv_1_18[0][0]']
#  tion)
#
#  activation_249 (Activation)    (None, 11, 11, 672)  0           ['normal_bn_1_18[0][0]']
#
#  activation_251 (Activation)    (None, 11, 11, 672)  0           ['adjust_bn_18[0][0]']
#
#  activation_253 (Activation)    (None, 11, 11, 672)  0           ['adjust_bn_18[0][0]']
#
#  activation_255 (Activation)    (None, 11, 11, 672)  0           ['adjust_bn_18[0][0]']
#
#  activation_257 (Activation)    (None, 11, 11, 672)  0           ['normal_bn_1_18[0][0]']
#
#  separable_conv_1_normal_left1_  (None, 11, 11, 672)  468384     ['activation_249[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_normal_right1  (None, 11, 11, 672)  457632     ['activation_251[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_1_normal_left2_  (None, 11, 11, 672)  468384     ['activation_253[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_normal_right2  (None, 11, 11, 672)  457632     ['activation_255[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_1_normal_left5_  (None, 11, 11, 672)  457632     ['activation_257[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_1_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_left1_1
#  t1_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_right1_
#  ht1_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_left2_1
#  t2_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_1_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_right2_
#  ht2_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_1_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_1_normal_left5_1
#  t5_18 (BatchNormalization)                                      8[0][0]']
#
#  activation_250 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_left
#                                                                  1_18[0][0]']
#
#  activation_252 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t1_18[0][0]']
#
#  activation_254 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_left
#                                                                  2_18[0][0]']
#
#  activation_256 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_righ
#                                                                  t2_18[0][0]']
#
#  activation_258 (Activation)    (None, 11, 11, 672)  0           ['separable_conv_1_bn_normal_left
#                                                                  5_18[0][0]']
#
#  separable_conv_2_normal_left1_  (None, 11, 11, 672)  468384     ['activation_250[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_normal_right1  (None, 11, 11, 672)  457632     ['activation_252[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_2_normal_left2_  (None, 11, 11, 672)  468384     ['activation_254[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_normal_right2  (None, 11, 11, 672)  457632     ['activation_256[0][0]']
#  _18 (SeparableConv2D)
#
#  separable_conv_2_normal_left5_  (None, 11, 11, 672)  457632     ['activation_258[0][0]']
#  18 (SeparableConv2D)
#
#  separable_conv_2_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_left1_1
#  t1_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_right1_
#  ht1_18 (BatchNormalization)                                     18[0][0]']
#
#  separable_conv_2_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_left2_1
#  t2_18 (BatchNormalization)                                      8[0][0]']
#
#  separable_conv_2_bn_normal_rig  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_right2_
#  ht2_18 (BatchNormalization)                                     18[0][0]']
#
#  normal_left3_18 (AveragePoolin  (None, 11, 11, 672)  0          ['normal_bn_1_18[0][0]']
#  g2D)
#
#  normal_left4_18 (AveragePoolin  (None, 11, 11, 672)  0          ['adjust_bn_18[0][0]']
#  g2D)
#
#  normal_right4_18 (AveragePooli  (None, 11, 11, 672)  0          ['adjust_bn_18[0][0]']
#  ng2D)
#
#  separable_conv_2_bn_normal_lef  (None, 11, 11, 672)  2688       ['separable_conv_2_normal_left5_1
#  t5_18 (BatchNormalization)                                      8[0][0]']
#
#  normal_add_1_18 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  1_18[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t1_18[0][0]']
#
#  normal_add_2_18 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  2_18[0][0]',
#                                                                   'separable_conv_2_bn_normal_righ
#                                                                  t2_18[0][0]']
#
#  normal_add_3_18 (Add)          (None, 11, 11, 672)  0           ['normal_left3_18[0][0]',
#                                                                   'adjust_bn_18[0][0]']
#
#  normal_add_4_18 (Add)          (None, 11, 11, 672)  0           ['normal_left4_18[0][0]',
#                                                                   'normal_right4_18[0][0]']
#
#  normal_add_5_18 (Add)          (None, 11, 11, 672)  0           ['separable_conv_2_bn_normal_left
#                                                                  5_18[0][0]',
#                                                                   'normal_bn_1_18[0][0]']
#
#  normal_concat_18 (Concatenate)  (None, 11, 11, 4032  0          ['adjust_bn_18[0][0]',
#                                 )                                 'normal_add_1_18[0][0]',
#                                                                   'normal_add_2_18[0][0]',
#                                                                   'normal_add_3_18[0][0]',
#                                                                   'normal_add_4_18[0][0]',
#                                                                   'normal_add_5_18[0][0]']
#
#  activation_259 (Activation)    (None, 11, 11, 4032  0           ['normal_concat_18[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 487872)       0           ['activation_259[0][0]']
#
#  dense (Dense)                  (None, 4)            1951492     ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 86,868,310
# Trainable params: 1,951,492
# Non-trainable params: 84,916,818
# __________________________________________________________________________________________________

# %%
import tensorflow as tf

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc')
]

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=METRICS
)

# %%
# Use the Image Data Generator to import the images from the dataset
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# Make sure you provide the same target size as initialied for the image size
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Split/train',
                                                 target_size = (331, 331),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 913 images belonging to 4 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Split/val',
                                            target_size = (331, 331),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 231 images belonging to 4 classes.

# %%
# fit the model
# Run the cell. It will take some time to execute
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# <ipython-input-24-69229fe26ea3>:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   r = model.fit_generator(
# Epoch 1/50
# 29/29 [==============================] - 342s 11s/step - loss: 15.0740 - accuracy: 0.8395 - precision: 0.6819 - recall: 0.6714 - auc: 0.8087 - val_loss: 10.2314 - val_accuracy: 0.8810 - val_precision: 0.7619 - val_recall: 0.7619 - val_auc: 0.8508
# Epoch 2/50
# 29/29 [==============================] - 48s 2s/step - loss: 5.9837 - accuracy: 0.9179 - precision: 0.8357 - recall: 0.8357 - auc: 0.9020 - val_loss: 7.6455 - val_accuracy: 0.8723 - val_precision: 0.7446 - val_recall: 0.7446 - val_auc: 0.8399
# Epoch 3/50
# 29/29 [==============================] - 48s 2s/step - loss: 4.8265 - accuracy: 0.9343 - precision: 0.8686 - recall: 0.8686 - auc: 0.9199 - val_loss: 5.9234 - val_accuracy: 0.9221 - val_precision: 0.8442 - val_recall: 0.8442 - val_auc: 0.9070
# Epoch 4/50
# 29/29 [==============================] - 48s 2s/step - loss: 3.0804 - accuracy: 0.9491 - precision: 0.8981 - recall: 0.8981 - auc: 0.9425 - val_loss: 6.8706 - val_accuracy: 0.9026 - val_precision: 0.8052 - val_recall: 0.8052 - val_auc: 0.8801
# Epoch 5/50
# 29/29 [==============================] - 48s 2s/step - loss: 3.1753 - accuracy: 0.9556 - precision: 0.9113 - recall: 0.9113 - auc: 0.9492 - val_loss: 6.5509 - val_accuracy: 0.9069 - val_precision: 0.8139 - val_recall: 0.8139 - val_auc: 0.8937
# Epoch 6/50
# 29/29 [==============================] - 48s 2s/step - loss: 2.7109 - accuracy: 0.9622 - precision: 0.9244 - recall: 0.9244 - auc: 0.9536 - val_loss: 9.0114 - val_accuracy: 0.8874 - val_precision: 0.7749 - val_recall: 0.7749 - val_auc: 0.8625
# Epoch 7/50
# 29/29 [==============================] - 48s 2s/step - loss: 2.9558 - accuracy: 0.9589 - precision: 0.9179 - recall: 0.9179 - auc: 0.9535 - val_loss: 10.8688 - val_accuracy: 0.8658 - val_precision: 0.7316 - val_recall: 0.7316 - val_auc: 0.8403
# Epoch 8/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.9416 - accuracy: 0.9699 - precision: 0.9398 - recall: 0.9398 - auc: 0.9647 - val_loss: 8.0054 - val_accuracy: 0.9177 - val_precision: 0.8355 - val_recall: 0.8355 - val_auc: 0.9058
# Epoch 9/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.7022 - accuracy: 0.9721 - precision: 0.9441 - recall: 0.9441 - auc: 0.9706 - val_loss: 9.3857 - val_accuracy: 0.9199 - val_precision: 0.8398 - val_recall: 0.8398 - val_auc: 0.8990
# Epoch 10/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.9291 - accuracy: 0.9677 - precision: 0.9354 - recall: 0.9354 - auc: 0.9585 - val_loss: 8.8064 - val_accuracy: 0.9177 - val_precision: 0.8355 - val_recall: 0.8355 - val_auc: 0.8949
# Epoch 11/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.9857 - accuracy: 0.9748 - precision: 0.9496 - recall: 0.9496 - auc: 0.9707 - val_loss: 7.9396 - val_accuracy: 0.9264 - val_precision: 0.8528 - val_recall: 0.8528 - val_auc: 0.9104
# Epoch 12/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.1415 - accuracy: 0.9797 - precision: 0.9595 - recall: 0.9595 - auc: 0.9780 - val_loss: 8.0701 - val_accuracy: 0.9069 - val_precision: 0.8139 - val_recall: 0.8139 - val_auc: 0.8947
# Epoch 13/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.5557 - accuracy: 0.9792 - precision: 0.9584 - recall: 0.9584 - auc: 0.9772 - val_loss: 8.2529 - val_accuracy: 0.8896 - val_precision: 0.7792 - val_recall: 0.7792 - val_auc: 0.8676
# Epoch 14/50
# 29/29 [==============================] - 49s 2s/step - loss: 1.1195 - accuracy: 0.9847 - precision: 0.9693 - recall: 0.9693 - auc: 0.9840 - val_loss: 9.7498 - val_accuracy: 0.9113 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8886
# Epoch 15/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.8736 - accuracy: 0.9797 - precision: 0.9595 - recall: 0.9595 - auc: 0.9765 - val_loss: 9.9744 - val_accuracy: 0.9069 - val_precision: 0.8139 - val_recall: 0.8139 - val_auc: 0.8859
# Epoch 16/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.7041 - accuracy: 0.9737 - precision: 0.9474 - recall: 0.9474 - auc: 0.9715 - val_loss: 11.1304 - val_accuracy: 0.9113 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8917
# Epoch 17/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.0796 - accuracy: 0.9863 - precision: 0.9726 - recall: 0.9726 - auc: 0.9846 - val_loss: 11.3611 - val_accuracy: 0.9004 - val_precision: 0.8009 - val_recall: 0.8009 - val_auc: 0.8729
# Epoch 18/50
# 29/29 [==============================] - 49s 2s/step - loss: 1.8526 - accuracy: 0.9792 - precision: 0.9584 - recall: 0.9584 - auc: 0.9765 - val_loss: 13.2456 - val_accuracy: 0.9113 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8868
# Epoch 19/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.9821 - accuracy: 0.9830 - precision: 0.9660 - recall: 0.9660 - auc: 0.9802 - val_loss: 10.1517 - val_accuracy: 0.9221 - val_precision: 0.8442 - val_recall: 0.8442 - val_auc: 0.9038
# Epoch 20/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.0985 - accuracy: 0.9825 - precision: 0.9650 - recall: 0.9650 - auc: 0.9795 - val_loss: 12.5259 - val_accuracy: 0.9048 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.8774
# Epoch 21/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.0677 - accuracy: 0.9863 - precision: 0.9726 - recall: 0.9726 - auc: 0.9824 - val_loss: 11.1924 - val_accuracy: 0.9177 - val_precision: 0.8355 - val_recall: 0.8355 - val_auc: 0.8923
# Epoch 22/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.9562 - accuracy: 0.9858 - precision: 0.9715 - recall: 0.9715 - auc: 0.9824 - val_loss: 10.7793 - val_accuracy: 0.9221 - val_precision: 0.8442 - val_recall: 0.8442 - val_auc: 0.8959
# Epoch 23/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.7058 - accuracy: 0.9896 - precision: 0.9792 - recall: 0.9792 - auc: 0.9883 - val_loss: 16.5324 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8838
# Epoch 24/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.0746 - accuracy: 0.9869 - precision: 0.9737 - recall: 0.9737 - auc: 0.9855 - val_loss: 11.6479 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8890
# Epoch 25/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.5293 - accuracy: 0.9901 - precision: 0.9803 - recall: 0.9803 - auc: 0.9877 - val_loss: 13.2223 - val_accuracy: 0.8874 - val_precision: 0.7749 - val_recall: 0.7749 - val_auc: 0.8611
# Epoch 26/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.1379 - accuracy: 0.9885 - precision: 0.9770 - recall: 0.9770 - auc: 0.9854 - val_loss: 12.2131 - val_accuracy: 0.9113 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8911
# Epoch 27/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.9309 - accuracy: 0.9885 - precision: 0.9770 - recall: 0.9770 - auc: 0.9882 - val_loss: 12.5822 - val_accuracy: 0.9069 - val_precision: 0.8139 - val_recall: 0.8139 - val_auc: 0.8851
# Epoch 28/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.7243 - accuracy: 0.9901 - precision: 0.9803 - recall: 0.9803 - auc: 0.9868 - val_loss: 10.6754 - val_accuracy: 0.9199 - val_precision: 0.8398 - val_recall: 0.8398 - val_auc: 0.8988
# Epoch 29/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.6532 - accuracy: 0.9880 - precision: 0.9759 - recall: 0.9759 - auc: 0.9854 - val_loss: 12.1762 - val_accuracy: 0.9069 - val_precision: 0.8139 - val_recall: 0.8139 - val_auc: 0.8838
# Epoch 30/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.8858 - accuracy: 0.9907 - precision: 0.9814 - recall: 0.9814 - auc: 0.9876 - val_loss: 12.2434 - val_accuracy: 0.8983 - val_precision: 0.7965 - val_recall: 0.7965 - val_auc: 0.8701
# Epoch 31/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.7265 - accuracy: 0.9896 - precision: 0.9792 - recall: 0.9792 - auc: 0.9875 - val_loss: 11.8720 - val_accuracy: 0.9221 - val_precision: 0.8442 - val_recall: 0.8442 - val_auc: 0.8983
# Epoch 32/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.9988 - accuracy: 0.9901 - precision: 0.9803 - recall: 0.9803 - auc: 0.9868 - val_loss: 12.9662 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8787
# Epoch 33/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.1182 - accuracy: 0.9907 - precision: 0.9814 - recall: 0.9814 - auc: 0.9876 - val_loss: 14.7925 - val_accuracy: 0.9026 - val_precision: 0.8052 - val_recall: 0.8052 - val_auc: 0.8803
# Epoch 34/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.9265 - accuracy: 0.9890 - precision: 0.9781 - recall: 0.9781 - auc: 0.9868 - val_loss: 12.3608 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8867
# Epoch 35/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.5138 - accuracy: 0.9912 - precision: 0.9825 - recall: 0.9825 - auc: 0.9898 - val_loss: 13.8913 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8838
# Epoch 36/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.9153 - accuracy: 0.9890 - precision: 0.9781 - recall: 0.9781 - auc: 0.9868 - val_loss: 13.4100 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8841
# Epoch 37/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.1838 - accuracy: 0.9973 - precision: 0.9945 - recall: 0.9945 - auc: 0.9963 - val_loss: 14.0525 - val_accuracy: 0.9134 - val_precision: 0.8268 - val_recall: 0.8268 - val_auc: 0.8868
# Epoch 38/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.7122 - accuracy: 0.9923 - precision: 0.9847 - recall: 0.9847 - auc: 0.9905 - val_loss: 13.3413 - val_accuracy: 0.9048 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.8741
# Epoch 39/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.3175 - accuracy: 0.9951 - precision: 0.9901 - recall: 0.9901 - auc: 0.9934 - val_loss: 14.8366 - val_accuracy: 0.9069 - val_precision: 0.8139 - val_recall: 0.8139 - val_auc: 0.8764
# Epoch 40/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.5496 - accuracy: 0.9912 - precision: 0.9825 - recall: 0.9825 - auc: 0.9898 - val_loss: 15.7435 - val_accuracy: 0.9048 - val_precision: 0.8095 - val_recall: 0.8095 - val_auc: 0.8864
# Epoch 41/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.2915 - accuracy: 0.9951 - precision: 0.9901 - recall: 0.9901 - auc: 0.9956 - val_loss: 15.3855 - val_accuracy: 0.8961 - val_precision: 0.7922 - val_recall: 0.7922 - val_auc: 0.8689
# Epoch 42/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.8386 - accuracy: 0.9907 - precision: 0.9814 - recall: 0.9814 - auc: 0.9897 - val_loss: 16.1037 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8809
# Epoch 43/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.4460 - accuracy: 0.9918 - precision: 0.9836 - recall: 0.9836 - auc: 0.9905 - val_loss: 19.7220 - val_accuracy: 0.8983 - val_precision: 0.7965 - val_recall: 0.7965 - val_auc: 0.8642
# Epoch 44/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.9505 - accuracy: 0.9923 - precision: 0.9847 - recall: 0.9847 - auc: 0.9905 - val_loss: 15.7336 - val_accuracy: 0.9113 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8893
# Epoch 45/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.5826 - accuracy: 0.9923 - precision: 0.9847 - recall: 0.9847 - auc: 0.9898 - val_loss: 16.4463 - val_accuracy: 0.9134 - val_precision: 0.8268 - val_recall: 0.8268 - val_auc: 0.8843
# Epoch 46/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.4276 - accuracy: 0.9929 - precision: 0.9858 - recall: 0.9858 - auc: 0.9905 - val_loss: 15.6676 - val_accuracy: 0.9113 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8869
# Epoch 47/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.5274 - accuracy: 0.9923 - precision: 0.9847 - recall: 0.9847 - auc: 0.9912 - val_loss: 15.9271 - val_accuracy: 0.8983 - val_precision: 0.7965 - val_recall: 0.7965 - val_auc: 0.8672
# Epoch 48/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.4706 - accuracy: 0.9945 - precision: 0.9890 - recall: 0.9890 - auc: 0.9941 - val_loss: 14.8659 - val_accuracy: 0.9134 - val_precision: 0.8268 - val_recall: 0.8268 - val_auc: 0.8832
# Epoch 49/50
# 29/29 [==============================] - 48s 2s/step - loss: 0.3432 - accuracy: 0.9956 - precision: 0.9912 - recall: 0.9912 - auc: 0.9949 - val_loss: 15.5202 - val_accuracy: 0.9026 - val_precision: 0.8052 - val_recall: 0.8052 - val_auc: 0.8716
# Epoch 50/50
# 29/29 [==============================] - 48s 2s/step - loss: 1.3211 - accuracy: 0.9880 - precision: 0.9759 - recall: 0.9759 - auc: 0.9839 - val_loss: 16.4955 - val_accuracy: 0.9091 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8886

# %%
#%% PLOTTING RESULTS (Train vs Validation FOLDER 1)

def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,recall, val_recall):
    
    fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])

    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    
    ax3.plot(range(1, len(auc) + 1), auc)
    ax3.plot(range(1, len(val_auc) + 1), val_auc)
    ax3.set_title('History of AUC')
    ax3.set_xlabel('Epochs')
    ax3.set_ylabel('AUC')
    ax3.legend(['training', 'validation'])

    ax4.plot(range(1, len(precision) + 1), precision)
    ax4.plot(range(1, len(val_precision) + 1), val_precision)
    ax4.set_title('History of Precision')
    ax4.set_xlabel('Epochs')
    ax4.set_ylabel('Precision')
    ax4.legend(['training', 'validation'])
    
    ax5.plot(range(1, len(recall) + 1), recall)
    ax5.plot(range(1, len(val_recall) + 1), val_recall)
    ax5.set_title('History of recall')
    ax5.set_xlabel('Epochs')
    ax5.set_ylabel('Recall')
    ax5.legend(['training', 'validation'])

plt.show()
    

Train_Val_Plot(r.history['accuracy'],r.history['val_accuracy'],
               r.history['loss'],r.history['val_loss'],
               r.history['auc'],r.history['val_auc'],
               r.history['precision'],r.history['val_precision'],
               r.history['recall'],r.history['val_recall']
              )
